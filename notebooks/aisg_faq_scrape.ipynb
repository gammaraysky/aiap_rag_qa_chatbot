# %%
# %load_ext autoreload
# %autoreload 2
import requests
import pandas as pd
import numpy as np
from time import sleep 
from bs4 import BeautifulSoup

# %%
import re 

def clean_text(text, cleaning_tag=0):
    if cleaning_tag == 1:
        text = text.replace("\nOutcompute to outcompete | Growing our own timber\n", "")
    elif cleaning_tag == 2:
        text = text.replace("Best regards,", "")
        text = text.replace("Gayathriy", "")
    # Define regular expression patterns to match the strings to be removed
    pattern1 = r"This post was modified \d+ weeks ago \d+ times by"
    pattern2 = r"This post was modified \d+ weeks ago by"

    # Use re.sub() to replace the matched patterns with an empty string
    text = re.sub(pattern1, '', text)
    text = re.sub(pattern2, '', text)
    return text

def scrape_data(url, title, cleaning_tag=0):
    '''
    Inputs:
        - URL
        - title (str)
        - cleaning_tag (int)
            - if tag = 1, remove 'Outcompute to outcompete | Growing our own timber' from post
            - if tag = 2, remove 'Best regards,Gayathriy' from post
    Outputs:
        - dataframe with two columns - title and text 
    '''
    source = requests.get(url).text
    docs = [BeautifulSoup(source, "html.parser")] 
    nestedqns = [doc.find_all('a', class_='wpforo-topic-title') for doc in docs]
    questions = []
    answers = []

    for category in nestedqns:
        for qn in category:
            questions.append(qn['title'])
            sleep(np.random.random()/2)
            ans_source = requests.get(qn['href']).text
            ans_doc = BeautifulSoup(ans_source, "html.parser")
            answer_div = ans_doc.find('div', class_='post-wrap wpfn-2 wpf-answer-wrap')
            if answer_div:
                answer = answer_div.find('div', class_="wpforo-post-content").text
                answers.append(answer)
            else:
                answers.append("")

    df = pd.DataFrame({
        'questions' : questions,
        'answers' : answers,
    })
    '''
    # Combine the question and answer columns into a new text column
    df['text'] = df.apply(lambda row: row['questions'] + ' ' + row['answers'], axis=1)
    # Drop questions and answers columns
    df.drop(['questions', 'answers'], axis=1, inplace=True)
    '''
    # Add title column
    df['title'] = title 
    # Re-arrange columns
    df['answers'] = df['answers'].apply(clean_text, cleaning_tag = cleaning_tag)
    # Print the updated dataframe
    print(df)

    return df

# %%
faq_urls = {
    '100E': 'https://epoch.aisingapore.org/community/faq-100e/',
    'AI Apprencticeship Program (AIAP)': 'https://epoch.aisingapore.org/community/faq-aiap/',
    'Hiring AI Talent': 'https://epoch.aisingapore.org/community/hiring-ai-talents/',
    'LearnAI: AI for Everyone (AI4E)': 'https://epoch.aisingapore.org/community/faq-ai4e/',
    'LearnAI: AI for Industry (AI4I)': 'https://epoch.aisingapore.org/community/faq-ai4i/',
    'LearnAI: AI for Students (AI4S)': 'https://epoch.aisingapore.org/community/faq-ai4s/',
    'LearnAI: AI for Kids (AI4K)': 'https://epoch.aisingapore.org/community/faq-ai4k/',
    'LearnAI: AI Student Outreach Program': 'https://epoch.aisingapore.org/community/faq-aisop/',
    'LearnAI: Teacher Work Attachment Program': 'https://epoch.aisingapore.org/community/teacher-work-attachment-plus-programme-twapp/',
    'LearnAI: My LearnAI Account': 'https://epoch.aisingapore.org/community/my-learnai-account/',
    'LearnAI: Fees': 'https://epoch.aisingapore.org/community/fees-and-payment/',
    'LearnAI: Promotions': 'https://epoch.aisingapore.org/community/promotions/',
    'LearnAI: Datacamp': 'https://epoch.aisingapore.org/community/faq-datacamp/',
    'LearnAI: International Maths Day': 'https://epoch.aisingapore.org/community/international-maths-day/'
}

tags = {
    '100E': 1,
    'AI Apprencticeship Program (AIAP)': 1,
    'Hiring AI Talent': 1,
    'LearnAI: AI for Everyone (AI4E)': 2,
    'LearnAI: AI for Industry (AI4I)': 2,
    'LearnAI: AI for Students (AI4S)': 2,
    'LearnAI: AI for Kids (AI4K)': 2,
    'LearnAI: AI Student Outreach Program': 2,
    'LearnAI: Teacher Work Attachment Program': 2,
    'LearnAI: My LearnAI Account': 2,
    'LearnAI: Fees': 2,
    'LearnAI: Promotions': 2,
    'LearnAI: Datacamp': 2,
    'LearnAI: International Maths Day': 2
}

# %%
dfs = {}

for title, url in faq_urls.items():
    dfs[title] = scrape_data(url = url, title=title, cleaning_tag=tags[title])
# Out:
#                                            questions  \
# 0  What are the differences between 100 Experimen...
# 1  How does an organisation apply for the 100 Exp...
# 2  What are my responsibilities as a Project Spon...
# 3           Can I have AI apprentices on my project?
# 4  Who can be the Principal Investigator (PI) or ...
# 5  How long does it take for my proposal to be ap...
# 6                What if I do not have any datasets?
# 7            When is the cash contribution required?
# 8             What does 'in-kind contribution' mean?
# 9                        Who are the AI apprentices?
#
#                                              answers title
# 0  \n\n\n\n \n100E4I\n100E4R\n\n\n\nCollaboration...  100E
# 1  \nAISG will provide the templates for an organ...  100E
# 2  \nTo ensure a successful outcome from the 100E...  100E
# 3  \nAI apprentices will be assigned for all 7-mo...  100E
# 4  \nThe 100E PI (and Co-PI) has to be a full-tim...  100E
# 5  \nThe review of the proposal and the sample da...  100E
# 6  \nDatasets are fundamental to developing any d...  100E
# 7  \nThe total cash (including the Indirect Resea...  100E
# 8  \nProject Sponsor’s in-kind contributions comp...  100E
# 9  \n\n\nThe AI apprentices are Singaporeans who ...  100E
#                                            questions  \
# 0          How can I prepare for the AIAP programme?
# 1  What type of candidates are we looking for in ...
# 2             "Eligible for TeSA CLT / TMCA Funding"
# 3  How is the Technical Assessment and Interview ...
# 4  What is the difference between the 9 and 12 mo...
# 5         What are the laptop requirements for AIAP?
# 6             What if I decided to drop out of AIAP?
# 7  How much is the monthly stipend and how is the...
# 8  Why do I need to have 2 guarantors when I acce...
# 9  What AI tools and frameworks would the AIAP ap...
#
#                                              answers  \
# 0  \nThis is one of the most frequent question, a...
# 1  \nWe are looking for candidates who possess a ...
# 2       \nThe requirements have always been there..
# 3  \nRefer to the article on AIAP® Assessment here\n
# 4  \n\n\n\nProgramme Period\n9 Months\n12 Months\...
# 5  \n\n\n\n\n\n\n\n\n\nYou are required to use yo...
# 6  \n\n\n\n\n\n\n\n\n\nAs AIAP is a fully sponsor...
# 7  \nThe monthly training allowance or stipend va...
# 8  \nAIAP is a fully sponsored programme by the S...
# 9  \n\n\n\n\n\n\n\n\n\nMost of the projects done ...
#
#                                title
# 0  AI Apprencticeship Program (AIAP)
# 1  AI Apprencticeship Program (AIAP)
# 2  AI Apprencticeship Program (AIAP)
# 3  AI Apprencticeship Program (AIAP)
# 4  AI Apprencticeship Program (AIAP)
# 5  AI Apprencticeship Program (AIAP)
# 6  AI Apprencticeship Program (AIAP)
# 7  AI Apprencticeship Program (AIAP)
# 8  AI Apprencticeship Program (AIAP)
# 9  AI Apprencticeship Program (AIAP)
#                                  questions  \
# 0          How do I hire these AI Talents?
# 1     Can I hire these Talents as interns?
# 2  Do I have to pay talent placement fees?
# 3       How qualified are the Apprentices?
#
#                                              answers             title
# 0  \nYou can submit your JD via the job portal he...  Hiring AI Talent
# 1  \nIt is unlikley any of our apprentices will j...  Hiring AI Talent
# 2  \nThere are no costs for partnering us. Our go...  Hiring AI Talent
# 3  \nThe AIAP is a rigorous programme, and gradua...  Hiring AI Talent
#                                            questions  \
# 0         What if I am halfway through the old AI4E?
# 1  Do I get a new badge if I take AI4E (version 3...
# 2  What is the difference between the previous AI...
# 3  What will happen to my badge from the previous...
# 4  Why do you have a new version of AI4E (version...
# 5         How can I sign up for LearnAI AI4E course?
# 6                    When is the next AI4E workshop?
# 7       Will I get a AI4E certificate of completion?
# 8                       Is LearnAI AI4E course free?
# 9  After Completing The LearnAI AI4E Course, I Am...
#
#                                              answers  \
# 0  \nThe old AI4E is archived and you will not be...
# 1  \n\n\n\n\n\n\n\n\n\nIf you have completed the ...
# 2  \n\n\n\n\n\n\n\n\n\nWe have updated key AI con...
# 3  \n\nIt remains listed in your learning dashboa...
# 4  \nWe refresh our learning content regularly so...
# 5  \nSign up for LearnAI as a free member here to...
# 6  \nWe have conducted our last live-streamed ses...
# 7  \n\n\n\n\n\n\n\n\n\nUpon completion of our Lea...
# 8  \n\n\n\n\n\n\n\n\n\nYes, the AI4E course is fr...
# 9  \nUpon completion of the LearnAI AI4E courses,...
#
#                              title
# 0  LearnAI: AI for Everyone (AI4E)
# 1  LearnAI: AI for Everyone (AI4E)
# 2  LearnAI: AI for Everyone (AI4E)
# 3  LearnAI: AI for Everyone (AI4E)
# 4  LearnAI: AI for Everyone (AI4E)
# 5  LearnAI: AI for Everyone (AI4E)
# 6  LearnAI: AI for Everyone (AI4E)
# 7  LearnAI: AI for Everyone (AI4E)
# 8  LearnAI: AI for Everyone (AI4E)
# 9  LearnAI: AI for Everyone (AI4E)
#                                            questions  \
# 0  Will I get a new badge or certificate if I com...
# 1  What if I cannot finish the previous version o...
# 2              What if I decide to drop out of AI4I?
# 3              What are the pre-requisites for AI4I?
# 4  Do I have to give up my current job to join AI4I?
# 5  Who is AI4I for and what are the outcomes upon...
# 6  My AI4I programme period was extended and I pu...
# 7  Will I get a certificate at the end of the AI4...
# 8  Will I still have access to Datacamp upon comp...
# 9  I'm in the process of learning my Literacy in ...
#
#                                              answers  \
# 0  \n\n\nBoth courses will be awarded the same Li...
# 1  \n\n\nAccess to the previous version been remo...
# 2  \n\n\n\n\n\n\n\n\n\nOnce you enroll for the co...
# 3  \n\n\n\n\n\n\n\n\n\nWhile there are no pre-req...
# 4  \n\n\n\n\n\n\n\n\n\nNo. This course is designe...
# 5  \nAI4I is a fully online programme meant to pr...
# 6  \nThe DataCamp Premium Plan Access Code was se...
# 7  \nThe AI4I programme consists of 3 parts:\n1. ...
# 8  \n\n\n\n\n\n\n\n\n\nYour 12-month DataCamp sub...
# 9  \n\n\nYou can still continue to complete the p...
#
#                              title
# 0  LearnAI: AI for Industry (AI4I)
# 1  LearnAI: AI for Industry (AI4I)
# 2  LearnAI: AI for Industry (AI4I)
# 3  LearnAI: AI for Industry (AI4I)
# 4  LearnAI: AI for Industry (AI4I)
# 5  LearnAI: AI for Industry (AI4I)
# 6  LearnAI: AI for Industry (AI4I)
# 7  LearnAI: AI for Industry (AI4I)
# 8  LearnAI: AI for Industry (AI4I)
# 9  LearnAI: AI for Industry (AI4I)
#                                            questions  \
# 0  Can I change my AI4S group's start date? As th...
# 1  I would like to introduce AI to my students to...
# 2  Are there any projects that can be incorporate...
# 3  Will students receive a DataCamp certificate u...
# 4  I am an educator, can I extend my DataCamp gro...
# 5  Where can I find a list of all DataCamp's modu...
# 6       Who can apply for the AI4S (Educator) group?
# 7  Do students receive a certificate issued by AI...
#
#                                              answers  \
# 0  \n\n\nIf you need access before your class’s s...
# 1  \n\n\nWe recommend you to introduce AI Singapo...
# 2  \n\n\nStudents can apply what they learnt in c...
# 3  \n\n\nYes, students receive DataCamp certifica...
# 4  \n\n\nNo, you cannot extend your DataCamp grou...
# 5          \n\n\nYou can find it here.\n\n\n \n\n\n
# 6  \n\n\n\n\n\n\n\n\n\nAll teaching staff from lo...
# 7  \n\n\nUpon completion of the AI4S programme, a...
#
#                              title
# 0  LearnAI: AI for Students (AI4S)
# 1  LearnAI: AI for Students (AI4S)
# 2  LearnAI: AI for Students (AI4S)
# 3  LearnAI: AI for Students (AI4S)
# 4  LearnAI: AI for Students (AI4S)
# 5  LearnAI: AI for Students (AI4S)
# 6  LearnAI: AI for Students (AI4S)
# 7  LearnAI: AI for Students (AI4S)
#                                            questions  \
# 0  Where can I access the AI for Kids (AI4K)®Stor...
# 1  Can I arrange dedicated sessions for my school...
# 2  Will I be able to conduct the AI4K Bootcamp ou...
# 3  How long is the AI4K Certified Instructor cert...
# 4  How can I register/apply for AI4K Train-the-Tr...
# 5  Do I need to pay for the Train-the-Trainer (TTT)?
# 6        Can I use my SkillsFuture credits to apply?
# 7       When will I be awarded the AI4K certificate?
# 8              What is AI4K Train-the-Trainer (TTT)?
# 9              What is an AI4K Certified Instructor?
#
#                                              answers  \
# 0  \n\n\nYou can download the digital copy at our...
# 1  \n\n\nYes, the school must commit to a minimum...
# 2  \n\n\nNo. However, AISG/AI Learning Lab can or...
# 3          \n\n\nIt is valid for 2 years.\n\n\n\n\n
# 4  \n\n\nPlease contact us at AI Learning Lab at ...
# 5          \n\n\nYes, the fee is SGD 550.\n\n\n\n\n
# 6            \n\n\nNo, not at the moment.\n\n\n\n\n
# 7  \n\n\nYou are required to attend all 2 days co...
# 8  \n\n\nThis is a 2-day course conducted by our ...
# 9  \n\n\nThis is a certificate awarded to partici...
#
#                          title
# 0  LearnAI: AI for Kids (AI4K)
# 1  LearnAI: AI for Kids (AI4K)
# 2  LearnAI: AI for Kids (AI4K)
# 3  LearnAI: AI for Kids (AI4K)
# 4  LearnAI: AI for Kids (AI4K)
# 5  LearnAI: AI for Kids (AI4K)
# 6  LearnAI: AI for Kids (AI4K)
# 7  LearnAI: AI for Kids (AI4K)
# 8  LearnAI: AI for Kids (AI4K)
# 9  LearnAI: AI for Kids (AI4K)
#                                            questions  \
# 0  Which email address will the reimbursement not...
# 1                                 Unable to form SUG
# 2  For Level 3, I don’t wish to purchase the bund...
# 3                   Are all the courses held online?
# 4           Are the certificates awarded recognised?
# 5  What can I reimburse from the $100 fund for th...
# 6  I’m an IT student with good programming skills...
# 7  I don’t have any background in coding. Is this...
# 8  Can I form the Student User Group (SUG) with f...
#
#                                              answers  \
# 0  \nThe email address associated with your PayPa...
# 1  \nHi there, \nPlease refer to the FAQ link bel...
# 2  \nYes. In this case, please ignore the email a...
# 3  \nLevel 1 to 3 courses are self-directed learn...
# 4  \nEach level completion offers an industry-rec...
# 5  \nAISG will provide reimbursement* for worksho...
# 6  \nLevel 1 gives students a holistic view of AI...
# 7  \n\nLevel 1 is designed for beginners with no ...
# 8  \nWe encourage you to form the Student User Gr...
#
#                                   title
# 0  LearnAI: AI Student Outreach Program
# 1  LearnAI: AI Student Outreach Program
# 2  LearnAI: AI Student Outreach Program
# 3  LearnAI: AI Student Outreach Program
# 4  LearnAI: AI Student Outreach Program
# 5  LearnAI: AI Student Outreach Program
# 6  LearnAI: AI Student Outreach Program
# 7  LearnAI: AI Student Outreach Program
# 8  LearnAI: AI Student Outreach Program
#                                            questions  \
# 0  How do I sign-up for TWA+ Programme @ AI Singa...
# 1  Is TWA+ Programme @ AI Singapore applicable fo...
# 2             Does hybrid working arrangement apply?
# 3            When does the attachment start and end?
# 4                 Will I be paid for the attachment?
#
#                                              answers  \
# 0  \nTWA+ Programme is administered by the Academ...
# 1  \nAI Singapore welcomes educators from ITE, po...
# 2
# 3  \nTeachers will need to indicate their propose...
# 4  \nTeachers will still receive a salary from MO...
#
#                                       title
# 0  LearnAI: Teacher Work Attachment Program
# 1  LearnAI: Teacher Work Attachment Program
# 2  LearnAI: Teacher Work Attachment Program
# 3  LearnAI: Teacher Work Attachment Program
# 4  LearnAI: Teacher Work Attachment Program
#                                            questions  \
# 0  How do I change the name that appears on my ce...
# 1                                  Reset my password
# 2                 How do I delete my LearnAI account
# 3                  How do I change my email address?
# 4        Signing up and Logging into LearnAI account
# 5  How do I update my personal details for my Lea...
#
#                                              answers  \
# 0  \nFor a request for a name change on accredibl...
# 1  \nRefer to FAQ "Signing up and Logging into Le...
# 2  \nWrite to us by selecting the Category, Learn...
# 3  \nRefer to FAQ "How do I update my personal de...
# 4  \nCreating a LearnAI Account \n If you don't a...
# 5  \n1. Log in to your LearnAI account here and g...
#
#                          title
# 0  LearnAI: My LearnAI Account
# 1  LearnAI: My LearnAI Account
# 2  LearnAI: My LearnAI Account
# 3  LearnAI: My LearnAI Account
# 4  LearnAI: My LearnAI Account
# 5  LearnAI: My LearnAI Account
#                                            questions  \
# 0  What are the premium membership plan subscript...
# 1  How do I redeem a coupon code on the LearnAI s...
# 2  Is the LearnAI Premium Membership fee eligible...
#
#                                              answers          title
# 0  \nVisit the LearnAI website to learn more abou...  LearnAI: Fees
# 1  \nAt the checkout page, key in your coupon cod...  LearnAI: Fees
# 2  \nThe LearnAI Premium Membership fee is not el...  LearnAI: Fees
#                                            questions  \
# 0         How do I share my credentials on LinkedIn?
# 1  If I had completed ‘AI for Everyone Theory’ or...
# 2         How do I find the URL to my LinkedIn post?
# 3  Do I have to unlock all 5 promo codes to recei...
# 4           How do I unlock all 5 promotional codes?
# 5   Who is eligible for the 'Stack it up' promotion?
#
#                                              answers                title
# 0  \nUpon completion of the AI for Everyone Theor...  LearnAI: Promotions
# 1  \n\n\nYes, simply share your badge/certificate...  LearnAI: Promotions
# 2  \nStep 1: Go to your LinkedIn post\nStep 2: Cl...  LearnAI: Promotions
# 3  \n\n\n\n\n\n\n\n\n\nNo. You do not need to ent...  LearnAI: Promotions
# 4  \n\n\nStep 1: Complete ‘AI for Everyone Theory...  LearnAI: Promotions
# 5  \nAll LearnAI learners are eligible for the pr...  LearnAI: Promotions
#                                            questions  \
# 0  Where can I retrieve my DataCamp Premium Plan ...
# 1       How do I redeem the DataCamp Premium Access?
# 2  I checked that my subscription has expired on ...
# 3  I have forgotten the password of my DataCamp a...
# 4  I have two 12-month DataCamp Premium Plan Acce...
# 5  When does my DataCamp Premium Plan subscriptio...
# 6  Do I have to redeem my DataCamp Premium Plan A...
# 7  I already have a free DataCamp account, will I...
# 8  I have an existing DataCamp Premium Plan subsc...
#
#                                              answers              title
# 0  \nA. For learners who signed up for LearnAI Pr...  LearnAI: Datacamp
# 1  \n\n\nHow do I redeem the DataCamp Premium Acc...  LearnAI: Datacamp
# 2  \n\n\nA 2-week grace period is given after the...  LearnAI: Datacamp
# 3  \nStep 1: Log in to DataCamp\nStep 2: Click Ne...  LearnAI: Datacamp
# 4  \n\n\nYou have to redeem the first access code...  LearnAI: Datacamp
# 5  \n\n\nYour subscription will expire 12 months ...  LearnAI: Datacamp
# 6  \n\n\nThe DataCamp access code is valid for re...  LearnAI: Datacamp
# 7  \nYes! Your free DataCamp account will be conv...  LearnAI: Datacamp
# 8  \nPlease note that you will not be able to red...  LearnAI: Datacamp
#                       questions  \
# 0          Terms and Conditions
# 1  How to use the voucher code?
# 2     The voucher code validity
#
#                                              answers  \
# 0                                      \n\n\n\n\n\n
# 1  \nStep 1Sign up for a LearnAI account. Refer t...
# 2  \nThe voucher code, INTMD-Z5ZN, is valid from ...
#
#                               title
# 0  LearnAI: International Maths Day
# 1  LearnAI: International Maths Day
# 2  LearnAI: International Maths Day

# %%
concatenated_df = pd.concat(dfs.values())

# %%
concatenated_df = pd.read_csv('scraped_data.csv', index_col=0)

# %%
concatenated_df.head()
# Out:
#                                            questions  \
# 0  What are the differences between 100 Experimen...
# 1  How does an organisation apply for the 100 Exp...
# 2  What are my responsibilities as a Project Spon...
# 3           Can I have AI apprentices on my project?
# 4  Who can be the Principal Investigator (PI) or ...
#
#                                              answers title
# 0  \n\n\n\n \n100E4I\n100E4R\n\n\n\nCollaboration...  100E
# 1  \nAISG will provide the templates for an organ...  100E
# 2  \nTo ensure a successful outcome from the 100E...  100E
# 3  \nAI apprentices will be assigned for all 7-mo...  100E
# 4  \nThe 100E PI (and Co-PI) has to be a full-tim...  100E
